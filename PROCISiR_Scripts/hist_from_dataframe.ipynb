# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('Inpath/___means.csv')
dfcut=df.iloc[:,1:]   #3 for all stats, 1 for Fluor

print dfcut.describe(percentiles=[0.05, .10, .20,.30, .50,.75,.80, .90, .95])

#Area	Perim.	Circ.	AR	Round	Solidity	FluorMean

dfcut.hist(layout=(3,3), figsize=(14,14), bins=50, grid=False, color='b', alpha=0.5, edgecolor='None')

plt.show()
# Out:
#               Area       Perim.       Circ.          AR       Round  \
# count   617.000000   617.000000  617.000000  617.000000  617.000000
# mean   1846.968147   275.307358    0.420350    2.871706    0.481798
# std    1179.371099   162.348028    0.218897    1.914128    0.225444
# min     178.206897    51.547172    0.039367    1.019033    0.059071
# 5%      503.401379    97.646676    0.125132    1.133913    0.151062
# 10%     671.448276   107.971031    0.166979    1.221034    0.189966
# 20%     866.677931   136.514545    0.219903    1.475391    0.272536
# 30%    1100.296552   167.706216    0.261727    1.713790    0.332755
# 50%    1577.172414   245.518900    0.374138    2.272724    0.455724
# 75%    2404.800000   356.236067    0.567300    3.427138    0.646448
# 80%    2652.473333   386.341832    0.615462    3.835633    0.695428
# 90%    3285.758621   477.632331    0.738477    5.488858    0.822179
# 95%    3997.338161   546.636073    0.851634    6.694367    0.884005
# ...

# %%
area=dfcut.iloc[:,0]
#line5=431.87625
#line95=4398.248958
#line10=1654.228571
line90=3997.338161
area.hist(figsize=(8,4), bins=50, grid=False, color='b', alpha=0.5, edgecolor='None')
#plt.axvline(x=line5, linewidth=2, color='k')
#plt.axvline(x=line95, linewidth=2, color='k')
#plt.axvline(x=line10, linewidth=2, color='r')
plt.axvline(x=line90, linewidth=2, color='r')

# %%
perim=dfcut.iloc[:,1]
#line5=89.242329
#line95=660.335135
#line10=183.595714
line90=546.636073
perim.hist(figsize=(8,4), bins=50, grid=False, color='b', alpha=0.5, edgecolor='None')
#plt.axvline(x=line5, linewidth=2, color='k')
#plt.axvline(x=line95, linewidth=2, color='k')
#plt.axvline(x=line10, linewidth=2, color='r')
plt.axvline(x=line90, linewidth=2, color='r')

# %%
circ=dfcut.iloc[:,2]
#line5=0.107094
line95= 0.834039
#line10=0.246417
#line90=0.708317
circ.hist(figsize=(8,4), bins=50, grid=False, color='b', alpha=0.5, edgecolor='None')
#plt.axvline(x=line5, linewidth=2, color='k')
plt.axvline(x=line95, linewidth=2, color='r')
#plt.axvline(x=line10, linewidth=2, color='r')
#plt.axvline(x=line90, linewidth=2, color='r')

# %%
fluor=dfcut.iloc[:,6]
#line5=263.492000
#line95=0.775351
line10=479.339356
#line20=305.698218
#line30=332.898729
fluor.hist(figsize=(8,4), bins=200, grid=False, color='b', alpha=0.5, edgecolor='None')
#plt.axvline(x=line5, linewidth=2, color='k')
plt.axvline(x=line10, linewidth=2, color='r')
#plt.axvline(x=line20, linewidth=2, color='b')
#plt.axvline(x=line30, linewidth=2, color='g')
plt.xlim([0,6000])
# Out:
# (0, 6000)
